# %%
import pandas as pd
data = pd.read_csv('D:/CogDatasets/CogDatasets/CogDatasets/CogLoad1/data all/3caqi_sensors_test.csv')
#print(data)
data
# Out:
#                  datetime      timestamp user_id level   task         hr  \
# 0     2017-10-10 14:03:10  1507644189579   3caqi     0  quest  41.000000
# 1     2017-10-10 14:03:11  1507644190504   3caqi     0  quest  61.666667
# 2     2017-10-10 14:03:12  1507644191498   3caqi     0  quest  61.666667
# 3     2017-10-10 14:03:13  1507644192492   3caqi     0  quest  62.333333
# 4     2017-10-10 14:03:14  1507644193491   3caqi     0  quest  62.333333
# ...                   ...            ...     ...   ...    ...        ...
# 5103  2017-10-10 15:28:13  1507649292487   3caqi  post   post  59.000000
# 5104  2017-10-10 15:28:14  1507649293490   3caqi  post   post  59.333333
# 5105  2017-10-10 15:28:15  1507649294497   3caqi  post   post  59.666667
# 5106  2017-10-10 15:28:16  1507649295496   3caqi  post   post  59.666667
# 5107  2017-10-10 15:28:17  1507649296402   3caqi  post   post  60.000000
#
#            gsr        rr  temperature  TLX_mean  ...  TLX_physical_demand  \
# ...

# %%
df = pd.DataFrame(data)
print (df.dtypes)
# Out:
# datetime                object
# timestamp                int64
# user_id                 object
# level                   object
# task                    object
# hr                     float64
# gsr                    float64
# rr                     float64
# temperature            float64
# TLX_mean                 int64
# TLX_mental_demand        int64
# TLX_physical_demand      int64
# TLX_temporal_demand      int64
# TLX_performance          int64
# TLX_effort               int64
# TLX_frustration          int64
# band_ax                float64
# band_ay                float64
# band_az                float64
# opacity_median         float64
# opacity_std            float64
# dtype: object

# %%
data.isna().sum()
# Out:
# datetime               0
# timestamp              0
# user_id                0
# level                  0
# task                   0
# hr                     0
# gsr                    1
# rr                     0
# temperature            0
# TLX_mean               0
# TLX_mental_demand      0
# TLX_physical_demand    0
# TLX_temporal_demand    0
# TLX_performance        0
# TLX_effort             0
# TLX_frustration        0
# band_ax                0
# band_ay                0
# band_az                0
# opacity_median         0
# opacity_std            0
# dtype: int64

# %%
#data.groupby("task").hr.mean()
#data.groupby("task").hr.std()
#data.isna().sum()

# %%
data.dropna(inplace=True)
data.isna().sum()
# Out:
# datetime               0
# timestamp              0
# user_id                0
# level                  0
# task                   0
# hr                     0
# gsr                    0
# rr                     0
# temperature            0
# TLX_mean               0
# TLX_mental_demand      0
# TLX_physical_demand    0
# TLX_temporal_demand    0
# TLX_performance        0
# TLX_effort             0
# TLX_frustration        0
# band_ax                0
# band_ay                0
# band_az                0
# opacity_median         0
# opacity_std            0
# dtype: int64

# %%
#data_quest = pd.DataFrame(columns=["task", "hr"])
#data_quest.head()

# %%
data
# Out:
#                  datetime      timestamp user_id level   task         hr  \
# 1     2017-10-10 14:03:11  1507644190504   3caqi     0  quest  61.666667
# 2     2017-10-10 14:03:12  1507644191498   3caqi     0  quest  61.666667
# 3     2017-10-10 14:03:13  1507644192492   3caqi     0  quest  62.333333
# 4     2017-10-10 14:03:14  1507644193491   3caqi     0  quest  62.333333
# 5     2017-10-10 14:03:15  1507644194494   3caqi     0  quest  62.333333
# ...                   ...            ...     ...   ...    ...        ...
# 5103  2017-10-10 15:28:13  1507649292487   3caqi  post   post  59.000000
# 5104  2017-10-10 15:28:14  1507649293490   3caqi  post   post  59.333333
# 5105  2017-10-10 15:28:15  1507649294497   3caqi  post   post  59.666667
# 5106  2017-10-10 15:28:16  1507649295496   3caqi  post   post  59.666667
# 5107  2017-10-10 15:28:17  1507649296402   3caqi  post   post  60.000000
#
#            gsr        rr  temperature  TLX_mean  ...  TLX_physical_demand  \
# ...

# %%
#data.drop(data.TLX_mean == -1)
#i = data[(data.TLX_mean == -1)].index
#print (i)

# %%
#data.drop(data[data['TLX_mean'] == -1].index, inplace=True)

#delete 240 -1 during test
#df.drop(df[(df['Unit_Price'] >400) & (df['Unit_Price'] < 600)].index, inplace=True)
data.drop(data[(data['TLX_mean'] == -1) & (data.task.str.contains('rest|quest|post')==False)].index, inplace=True)
data
# Out:
#                  datetime      timestamp user_id level   task         hr  \
# 1     2017-10-10 14:03:11  1507644190504   3caqi     0  quest  61.666667
# 2     2017-10-10 14:03:12  1507644191498   3caqi     0  quest  61.666667
# 3     2017-10-10 14:03:13  1507644192492   3caqi     0  quest  62.333333
# 4     2017-10-10 14:03:14  1507644193491   3caqi     0  quest  62.333333
# 5     2017-10-10 14:03:15  1507644194494   3caqi     0  quest  62.333333
# ...                   ...            ...     ...   ...    ...        ...
# 5103  2017-10-10 15:28:13  1507649292487   3caqi  post   post  59.000000
# 5104  2017-10-10 15:28:14  1507649293490   3caqi  post   post  59.333333
# 5105  2017-10-10 15:28:15  1507649294497   3caqi  post   post  59.666667
# 5106  2017-10-10 15:28:16  1507649295496   3caqi  post   post  59.666667
# 5107  2017-10-10 15:28:17  1507649296402   3caqi  post   post  60.000000
#
#            gsr        rr  temperature  TLX_mean  ...  TLX_physical_demand  \
# ...

# %%
data[data.TLX_mean < 10]
# Out:
#                  datetime      timestamp user_id level   task         hr  \
# 1     2017-10-10 14:03:11  1507644190504   3caqi     0  quest  61.666667
# 2     2017-10-10 14:03:12  1507644191498   3caqi     0  quest  61.666667
# 3     2017-10-10 14:03:13  1507644192492   3caqi     0  quest  62.333333
# 4     2017-10-10 14:03:14  1507644193491   3caqi     0  quest  62.333333
# 5     2017-10-10 14:03:15  1507644194494   3caqi     0  quest  62.333333
# ...                   ...            ...     ...   ...    ...        ...
# 5103  2017-10-10 15:28:13  1507649292487   3caqi  post   post  59.000000
# 5104  2017-10-10 15:28:14  1507649293490   3caqi  post   post  59.333333
# 5105  2017-10-10 15:28:15  1507649294497   3caqi  post   post  59.666667
# 5106  2017-10-10 15:28:16  1507649295496   3caqi  post   post  59.666667
# 5107  2017-10-10 15:28:17  1507649296402   3caqi  post   post  60.000000
#
#            gsr        rr  temperature  TLX_mean  ...  TLX_physical_demand  \
# ...

# %%
data[data.TLX_mean < 20]
# Out:
#                  datetime      timestamp user_id level   task         hr  \
# 1     2017-10-10 14:03:11  1507644190504   3caqi     0  quest  61.666667
# 2     2017-10-10 14:03:12  1507644191498   3caqi     0  quest  61.666667
# 3     2017-10-10 14:03:13  1507644192492   3caqi     0  quest  62.333333
# 4     2017-10-10 14:03:14  1507644193491   3caqi     0  quest  62.333333
# 5     2017-10-10 14:03:15  1507644194494   3caqi     0  quest  62.333333
# ...                   ...            ...     ...   ...    ...        ...
# 5103  2017-10-10 15:28:13  1507649292487   3caqi  post   post  59.000000
# 5104  2017-10-10 15:28:14  1507649293490   3caqi  post   post  59.333333
# 5105  2017-10-10 15:28:15  1507649294497   3caqi  post   post  59.666667
# 5106  2017-10-10 15:28:16  1507649295496   3caqi  post   post  59.666667
# 5107  2017-10-10 15:28:17  1507649296402   3caqi  post   post  60.000000
#
#            gsr        rr  temperature  TLX_mean  ...  TLX_physical_demand  \
# ...

# %%
#data[['hr','TLX_mean']].corr()
import numpy as np
# create a list of our conditions
conditions = [
    (data['TLX_mean'] == -1),
    (data['TLX_mean'] >= 0 ) & (data['TLX_mean'] < 10),
    (data['TLX_mean'] >= 10 ) & (data['TLX_mean'] < 20),
    (data['TLX_mean'] >=20)]
values = ['no', 'low', 'medium', 'high']
data['Stress'] = np.select(conditions, values)
data
# Out:
#                  datetime      timestamp user_id level   task         hr  \
# 1     2017-10-10 14:03:11  1507644190504   3caqi     0  quest  61.666667
# 2     2017-10-10 14:03:12  1507644191498   3caqi     0  quest  61.666667
# 3     2017-10-10 14:03:13  1507644192492   3caqi     0  quest  62.333333
# 4     2017-10-10 14:03:14  1507644193491   3caqi     0  quest  62.333333
# 5     2017-10-10 14:03:15  1507644194494   3caqi     0  quest  62.333333
# ...                   ...            ...     ...   ...    ...        ...
# 5103  2017-10-10 15:28:13  1507649292487   3caqi  post   post  59.000000
# 5104  2017-10-10 15:28:14  1507649293490   3caqi  post   post  59.333333
# 5105  2017-10-10 15:28:15  1507649294497   3caqi  post   post  59.666667
# 5106  2017-10-10 15:28:16  1507649295496   3caqi  post   post  59.666667
# 5107  2017-10-10 15:28:17  1507649296402   3caqi  post   post  60.000000
#
#            gsr        rr  temperature  TLX_mean  ...  TLX_temporal_demand  \
# ...

# %%
conditions1 = [
    (data['TLX_mean'] == -1),
    (data['TLX_mean'] != -1)]
values1 = ['no', 'yes']
data['binar'] = np.select(conditions1, values1)
data
# Out:
#                  datetime      timestamp user_id level   task         hr  \
# 1     2017-10-10 14:03:11  1507644190504   3caqi     0  quest  61.666667
# 2     2017-10-10 14:03:12  1507644191498   3caqi     0  quest  61.666667
# 3     2017-10-10 14:03:13  1507644192492   3caqi     0  quest  62.333333
# 4     2017-10-10 14:03:14  1507644193491   3caqi     0  quest  62.333333
# 5     2017-10-10 14:03:15  1507644194494   3caqi     0  quest  62.333333
# ...                   ...            ...     ...   ...    ...        ...
# 5103  2017-10-10 15:28:13  1507649292487   3caqi  post   post  59.000000
# 5104  2017-10-10 15:28:14  1507649293490   3caqi  post   post  59.333333
# 5105  2017-10-10 15:28:15  1507649294497   3caqi  post   post  59.666667
# 5106  2017-10-10 15:28:16  1507649295496   3caqi  post   post  59.666667
# 5107  2017-10-10 15:28:17  1507649296402   3caqi  post   post  60.000000
#
#            gsr        rr  temperature  TLX_mean  ...  TLX_performance  \
# ...

# %%
#data.boxplot(by =['Strese'], column =['hr'], grid = False)
data.boxplot(column = 'gsr', by = 'Stress')
data.boxplot(column = 'gsr', by = 'binar')
# Out:
# <AxesSubplot:title={'center':'gsr'}, xlabel='binar'>

# %%
data.boxplot(column = 'rr', by = 'Stress')
data.boxplot(column = 'rr', by = 'binar')
# Out:
# <AxesSubplot:title={'center':'rr'}, xlabel='binar'>

# %%
data.boxplot(column = 'hr', by = 'Stress')
data.boxplot(column = 'hr', by = 'binar')
# Out:
# <AxesSubplot:title={'center':'hr'}, xlabel='binar'>

# %%
data.boxplot(column = 'temperature', by = 'Stress')
data.boxplot(column = 'temperature', by = 'binar')
# Out:
# <AxesSubplot:title={'center':'temperature'}, xlabel='binar'>

# %%
data.binar.value_counts()
# Out:
# no     3165
# yes    1702
# Name: binar, dtype: int64

# %%
from matplotlib import pyplot as plt
data.plot(
   x='TLX_mean', 
   y='hr', 
   kind='scatter', 
   c='cornflowerblue'
)

plt.show()

# %%
data.plot(
   x='TLX_mean', 
   y='gsr', 
   kind='scatter', 
   c='cornflowerblue'
)
plt.show()

# %%
plt.show()
data.plot(
   x='TLX_mean', 
   y='temperature', 
   kind='scatter', 
   c='cornflowerblue'
)

plt.show()

# %%
data.plot(
   x='TLX_mean', 
   y='rr', 
   kind='scatter', 
   c='cornflowerblue'
)
plt.show()

# %%
#print(df[df.Name.str.contains(r'[^0-9a-zA-Z]') | df.Grade.str.contains(r'[@#&$%+-/*]')])
#.to_csv('file1.csv')

# %%
from scipy import stats
#from scipy.stats import mannwhitneyu, ttest_ind

# %%
[ShapiroTestS, pShapiroRR] = stats.shapiro(data['rr'])
if (pShapiroRR>0.05) : print('The RR is normal')
else: print('The RR is NOT normal')
    
[ShapiroTestS, pShapiroGSR] = stats.shapiro(data['gsr'])
if (pShapiroGSR>0.05) : print('The GSR is normal')
else: print('The GSR is NOT normal')
    
[ShapiroTestS, pShapiroTemp] = stats.shapiro(data['temperature'])
if (pShapiroTemp>0.05) : print('The temperature is normal')
else: print('The temperature is NOT normal')
    
[ShapiroTestS, pShapiroHR] = stats.shapiro(data['hr'])
if (pShapiroHR>0.05) : print('The HR is normal')
else: print('The HR is NOT normal')
# Out:
# The RR is NOT normal
# The GSR is NOT normal
# The temperature is NOT normal
# The HR is NOT normal

# %%
x1 = data.query('binar == "yes"')['hr'] 
y1 = data.query('binar == "no"')['hr']
if (pShapiroHR>0.05) :
    wHR, pvalueHR = stats.ttest_ind(x1, y1)  
    print ('t-test')
else: 
    wHR, pvalueHR = stats.mannwhitneyu(x1, y1)
    print ('u-test')
if (pvalueHR<0.05) : 
    interpret ='is significant difference'
else: 
    interpret=  'NOT significant difference'
print ('HR:  w=', wHR, '  p=', pvalueHR ,'---', interpret)


x2 = data.query('binar == "yes"')['rr'] 
y2 = data.query('binar == "no"')['rr']
if (pShapiroRR>0.05) :
    wRR, pvalueRR = stats.ttest_ind(x2, y2)  
    print ('t-test')
else: 
    wRR, pvalueRR = mannwhitneyu(x2, y2)
    print ('u-test')
if (pvalueRR<0.05) : 
    interpret ='is significant difference'
else: 
    interpret=  'NOT significant difference'
print ('RR:  w=', wRR, '  p=', pvalueRR ,'---', interpret)

x3 = data.query('binar == "yes"')['gsr'] 
y3 = data.query('binar == "no"')['gsr']
if (pShapiroGSR>0.05) :
    wGSR, pvalueGSR = stats.ttest_ind(x3, y3)  
    print ('t-test')
else: 
    wGSR, pvalueGSR = mannwhitneyu(x3, y3)
    print ('u-test')
if (pvalueGSR<0.05) : 
    interpret ='is significant difference'
else: 
    interpret=  'NOT significant difference'
print ('GSC: w=', wGSR, '  p=', pvalueGSR,'---', interpret)

x4 = data.query('binar == "yes"')['temperature'] 
y4 = data.query('binar == "no"')['temperature']
if (pShapiroTemp>0.05) :
    wTemp, pvalueTemp = stats.ttest_ind(x4, y4)  
    print ('t-test')
else: 
    wTemp, pvalueTemp = mannwhitneyu(x4, y4)
    print ('u-test')
if (pvalueTemp<0.05) : 
    interpret ='is significant difference'
else: 
    interpret=  'NOT significant difference'
print ('Temp:w=', wTemp, '  p=', pvalueTemp,'---', interpret)
# Out:
# u-test
# HR:  w= 2660107.0   p= 0.47605016392973587 --- NOT significant difference
# u-test
# RR:  w= 2932307.5   p= 3.2156312216282543e-07 --- is significant difference
# u-test
# GSC: w= 3346725.0   p= 2.1989382695686916e-44 --- is significant difference
# u-test
# Temp:w= 2701307.5   p= 0.8658976556172842 --- NOT significant difference
